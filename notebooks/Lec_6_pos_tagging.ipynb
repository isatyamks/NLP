# %%
#here we learn how to get the pos category of each words which we can use in lemmatization

# %%
import nltk

# %%
stop_words = nltk.corpus.stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
speech = """Good morning everyone,
It is an honor to be with you today. I want to speak about a topic that is very close to my heart: the power of dreams and how they shape the future of a nation.
India is a country rich in culture, resources, and above all, its youth. With over 65% of our population under the age of 35, we have the potential to be the world's leaders in science, technology, arts, and governance. But to achieve this, we must first dream.
Dreams are not what you see while sleeping; dreams are what keep you awake and motivated to achieve your goals. History is witness that every great accomplishment begins with a dream—a vision.
When we dreamed of freedom, we had leaders like Mahatma Gandhi who made it a reality. When we dreamed of self-reliance, we had scientists, engineers, and farmers who transformed our economy. Today, I urge each of you to dream of a stronger, self-sufficient, and united India.
Knowledge is the foundation of progress. It is your responsibility to constantly learn, innovate, and adapt. The world is changing rapidly with advancements in artificial intelligence, clean energy, and space exploration. We, as Indians, have the capability to lead in these fields.
When I worked on India's space program, we faced countless challenges. But every failure taught us something invaluable, and eventually, we succeeded. Remember, success does not come overnight—it demands hard work, perseverance, and teamwork."""

# %%
word_tk = nltk.word_tokenize(speech)

# %%
word_tk
# Out:
# ['Good',
#  'morning',
#  'everyone',
#  ',',
#  'It',
#  'is',
#  'an',
#  'honor',
#  'to',
#  'be',
#  'with',
#  'you',
#  'today',
#  '.',
#  'I',
#  'want',
#  'to',
#  'speak',
#  'about',
#  'a',
#  'topic',
#  'that',
#  'is',
#  'very',
#  'close',
#  'to',
#  'my',
#  'heart',
#  ':',
#  'the',
#  'power',
#  'of',
#  'dreams',
#  'and',
#  'how',
#  'they',
#  'shape',
#  'the',
#  'future',
#  'of',
#  'a',
#  'nation',
#  '.',
#  'India',
#  'is',
#  'a',
#  'country',
#  'rich',
#  'in',
#  'culture',
#  ',',
#  'resources',
#  ',',
#  'and',
#  'above',
#  'all',
#  ',',
#  'its',
#  'youth',
#  '.',
#  'With',
#  'over',
#  '65',
#  '%',
#  'of',
#  'our',
#  'population',
#  'under',
#  'the',
#  'age',
#  'of',
#  '35',
#  ',',
#  'we',
#  'have',
#  'the',
#  'potential',
#  'to',
#  'be',
#  'the',
#  'world',
#  "'s",
#  'leaders',
#  'in',
#  'science',
#  ',',
#  'technology',
#  ',',
#  'arts',
#  ',',
#  'and',
#  'governance',
#  '.',
#  'But',
#  'to',
# ...

# %%
result = []
for item in word_tk:
    if item not in stop_words:
        result.append(item)

result
# Out:
# ['Good',
#  'morning',
#  'everyone',
#  ',',
#  'It',
#  'honor',
#  'today',
#  '.',
#  'I',
#  'want',
#  'speak',
#  'topic',
#  'close',
#  'heart',
#  ':',
#  'power',
#  'dreams',
#  'shape',
#  'future',
#  'nation',
#  '.',
#  'India',
#  'country',
#  'rich',
#  'culture',
#  ',',
#  'resources',
#  ',',
#  ',',
#  'youth',
#  '.',
#  'With',
#  '65',
#  '%',
#  'population',
#  'age',
#  '35',
#  ',',
#  'potential',
#  'world',
#  "'s",
#  'leaders',
#  'science',
#  ',',
#  'technology',
#  ',',
#  'arts',
#  ',',
#  'governance',
#  '.',
#  'But',
#  'achieve',
#  ',',
#  'must',
#  'first',
#  'dream',
#  '.',
#  'Dreams',
#  'see',
#  'sleeping',
#  ';',
#  'dreams',
#  'keep',
#  'awake',
#  'motivated',
#  'achieve',
#  'goals',
#  '.',
#  'History',
#  'witness',
#  'every',
#  'great',
#  'accomplishment',
#  'begins',
#  'dream—a',
#  'vision',
#  '.',
#  'When',
#  'dreamed',
#  'freedom',
#  ',',
#  'leaders',
#  'like',
#  'Mahatma',
#  'Gandhi',
#  'made',
# ...

# %%
# now for each words we need to write the pos

# %%
import string  # for removing the , . /  and same characters

# %%
final_result=[]
for item in result:
    if item not in string.punctuation:
        final_result.append(item)

final_result
# Out:
# ['Good',
#  'morning',
#  'everyone',
#  'It',
#  'honor',
#  'today',
#  'I',
#  'want',
#  'speak',
#  'topic',
#  'close',
#  'heart',
#  'power',
#  'dreams',
#  'shape',
#  'future',
#  'nation',
#  'India',
#  'country',
#  'rich',
#  'culture',
#  'resources',
#  'youth',
#  'With',
#  '65',
#  'population',
#  'age',
#  '35',
#  'potential',
#  'world',
#  "'s",
#  'leaders',
#  'science',
#  'technology',
#  'arts',
#  'governance',
#  'But',
#  'achieve',
#  'must',
#  'first',
#  'dream',
#  'Dreams',
#  'see',
#  'sleeping',
#  'dreams',
#  'keep',
#  'awake',
#  'motivated',
#  'achieve',
#  'goals',
#  'History',
#  'witness',
#  'every',
#  'great',
#  'accomplishment',
#  'begins',
#  'dream—a',
#  'vision',
#  'When',
#  'dreamed',
#  'freedom',
#  'leaders',
#  'like',
#  'Mahatma',
#  'Gandhi',
#  'made',
#  'reality',
#  'When',
#  'dreamed',
#  'self-reliance',
#  'scientists',
#  'engineers',
#  'farmers',
#  'transformed',
#  'economy',
#  'Today',
#  'I',
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\isatyamks\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
words_with_pos=nltk.pos_tag(final_result)

# %%
words_with_pos
# Out:
# [('Good', 'JJ'),
#  ('morning', 'NN'),
#  ('everyone', 'NN'),
#  ('It', 'PRP'),
#  ('honor', 'VBD'),
#  ('today', 'NN'),
#  ('I', 'PRP'),
#  ('want', 'VBP'),
#  ('speak', 'JJ'),
#  ('topic', 'NN'),
#  ('close', 'JJ'),
#  ('heart', 'NN'),
#  ('power', 'NN'),
#  ('dreams', 'NNS'),
#  ('shape', 'VBP'),
#  ('future', 'JJ'),
#  ('nation', 'NN'),
#  ('India', 'NNP'),
#  ('country', 'NN'),
#  ('rich', 'JJ'),
#  ('culture', 'NN'),
#  ('resources', 'NNS'),
#  ('youth', 'VBP'),
#  ('With', 'IN'),
#  ('65', 'CD'),
#  ('population', 'NN'),
#  ('age', 'NN'),
#  ('35', 'CD'),
#  ('potential', 'JJ'),
#  ('world', 'NN'),
#  ("'s", 'POS'),
#  ('leaders', 'NNS'),
#  ('science', 'VBP'),
#  ('technology', 'NN'),
#  ('arts', 'NNS'),
#  ('governance', 'NN'),
#  ('But', 'CC'),
#  ('achieve', 'VB'),
#  ('must', 'MD'),
#  ('first', 'VB'),
#  ('dream', 'NN'),
#  ('Dreams', 'NNP'),
#  ('see', 'VBP'),
#  ('sleeping', 'VBG'),
#  ('dreams', 'NNS'),
#  ('keep', 'VB'),
#  ('awake', 'NN'),
#  ('motivated', 'JJ'),
# ...

# %%
#done
