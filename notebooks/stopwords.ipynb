# %%
import nltk

# %%
speech = """Good morning everyone,
It is an honor to be with you today. I want to speak about a topic that is very close to my heart: the power of dreams and how they shape the future of a nation.
India is a country rich in culture, resources, and above all, its youth. With over 65% of our population under the age of 35, we have the potential to be the world's leaders in science, technology, arts, and governance. But to achieve this, we must first dream.
Dreams are not what you see while sleeping; dreams are what keep you awake and motivated to achieve your goals. History is witness that every great accomplishment begins with a dream—a vision.
When we dreamed of freedom, we had leaders like Mahatma Gandhi who made it a reality. When we dreamed of self-reliance, we had scientists, engineers, and farmers who transformed our economy. Today, I urge each of you to dream of a stronger, self-sufficient, and united India.
Knowledge is the foundation of progress. It is your responsibility to constantly learn, innovate, and adapt. The world is changing rapidly with advancements in artificial intelligence, clean energy, and space exploration. We, as Indians, have the capability to lead in these fields.
When I worked on India's space program, we faced countless challenges. But every failure taught us something invaluable, and eventually, we succeeded. Remember, success does not come overnight—it demands hard work, perseverance, and teamwork."""

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\isatyamks\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_word = nltk.corpus.stopwords.words('english')

# %%
nltk.corpus.stopwords.words('german')
# Out:
# ['aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'also',
#  'am',
#  'an',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'der',
#  'den',
#  'des',
#  'dem',
#  'die',
#  'das',
#  'dass',
#  'daß',
#  'derselbe',
#  'derselben',
#  'denselben',
#  'desselben',
#  'demselben',
#  'dieselbe',
#  'dieselben',
#  'dasselbe',
#  'dazu',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'denn',
#  'derer',
#  'dessen',
#  'dich',
#  'dir',
#  'du',
#  'dies',
#  'diese',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'doch',
#  'dort',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einiges',
#  'einmal',
#  'er',
#  'ihn',
#  'ihm',
#  'es',
#  'etwas',
#  'euer',
#  'eure',
#  'eurem',
#  'euren',
#  'eurer',
#  'eures',
#  'für',
#  'gegen',
#  'gewesen',
#  'hab',
#  'habe',
#  'haben',
#  'hat',
#  'hatte',
#  'hatten',
#  'hier',
#  'hin',
#  'hinter',
#  'ich',
#  'mich',
#  'mir',
#  'ihr',
#  'ihre',
#  'ihrem',
#  'ihren',
#  'ihrer',
#  'ihres',
#  'euch',
#  'im',
#  'in',
#  'indem',
#  'ins',
#  'ist',
#  'jede',
#  'jedem',
#  'jeden',
#  'jeder',
#  'jedes',
#  'jene',
#  'jenem',
#  'jenen',
#  'jener',
#  'jenes',
#  'jetzt',
#  'kann',
#  'kein',
#  'keine',
#  'keinem',
#  'keinen',
#  'keiner',
#  'keines',
#  'können',
#  'könnte',
#  'machen',
#  'man',
#  'manche',
#  'manchem',
#  'manchen',
#  'mancher',
#  'manches',
#  'mein',
#  'meine',
#  'meinem',
#  'meinen',
#  'meiner',
#  'meines',
#  'mit',
#  'muss',
#  'musste',
#  'nach',
#  'nicht',
#  'nichts',
#  'noch',
#  'nun',
#  'nur',
#  'ob',
#  'oder',
#  'ohne',
#  'sehr',
#  'sein',
#  'seine',
#  'seinem',
#  'seinen',
#  'seiner',
#  'seines',
#  'selbst',
#  'sich',
#  'sie',
#  'ihnen',
#  'sind',
#  'so',
#  'solche',
#  'solchem',
#  'solchen',
#  'solcher',
#  'solches',
#  'soll',
#  'sollte',
#  'sondern',
#  'sonst',
#  'über',
#  'um',
#  'und',
#  'uns',
#  'unsere',
#  'unserem',
#  'unseren',
#  'unser',
#  'unseres',
#  'unter',
#  'viel',
#  'vom',
#  'von',
#  'vor',
#  'während',
#  'war',
#  'waren',
#  'warst',
#  'was',
#  'weg',
#  'weil',
#  'weiter',
#  'welche',
#  'welchem',
#  'welchen',
#  'welcher',
#  'welches',
#  'wenn',
#  'werde',
#  'werden',
#  'wie',
#  'wieder',
#  'will',
#  'wir',
#  'wird',
#  'wirst',
#  'wo',
#  'wollen',
#  'wollte',
#  'würde',
#  'würden',
#  'zu',
#  'zum',
#  'zur',
#  'zwar',
#  'zwischen']

# %%
sent_tk = nltk.sent_tokenize(speech)

# %%
sent_tk
# Out:
# ['Good morning everyone,\nIt is an honor to be with you today.',
#  'I want to speak about a topic that is very close to my heart: the power of dreams and how they shape the future of a nation.',
#  'India is a country rich in culture, resources, and above all, its youth.',
#  "With over 65% of our population under the age of 35, we have the potential to be the world's leaders in science, technology, arts, and governance.",
#  'But to achieve this, we must first dream.',
#  'Dreams are not what you see while sleeping; dreams are what keep you awake and motivated to achieve your goals.',
#  'History is witness that every great accomplishment begins with a dream—a vision.',
#  'When we dreamed of freedom, we had leaders like Mahatma Gandhi who made it a reality.',
#  'When we dreamed of self-reliance, we had scientists, engineers, and farmers who transformed our economy.',
#  'Today, I urge each of you to dream of a stronger, self-sufficient, and united India.',
#  'Knowledge is the foundation of progress.',
#  'It is your responsibility to constantly learn, innovate, and adapt.',
#  'The world is changing rapidly with advancements in artificial intelligence, clean energy, and space exploration.',
#  'We, as Indians, have the capability to lead in these fields.',
#  "When I worked on India's space program, we faced countless challenges.",
#  'But every failure taught us something invaluable, and eventually, we succeeded.',
#  'Remember, success does not come overnight—it demands hard work, perseverance, and teamwork.']

# %%
# words_list = []
# for sentence in sent_tk:
#     word_tk = nltk.word_tokenize(sentence)
#     words_list.append(word_tk)
#     print(word_tk)

# %%
words_list=nltk.word_tokenize(speech)

# %%
words_list
# Out:
# ['Good',
#  'morning',
#  'everyone',
#  ',',
#  'It',
#  'is',
#  'an',
#  'honor',
#  'to',
#  'be',
#  'with',
#  'you',
#  'today',
#  '.',
#  'I',
#  'want',
#  'to',
#  'speak',
#  'about',
#  'a',
#  'topic',
#  'that',
#  'is',
#  'very',
#  'close',
#  'to',
#  'my',
#  'heart',
#  ':',
#  'the',
#  'power',
#  'of',
#  'dreams',
#  'and',
#  'how',
#  'they',
#  'shape',
#  'the',
#  'future',
#  'of',
#  'a',
#  'nation',
#  '.',
#  'India',
#  'is',
#  'a',
#  'country',
#  'rich',
#  'in',
#  'culture',
#  ',',
#  'resources',
#  ',',
#  'and',
#  'above',
#  'all',
#  ',',
#  'its',
#  'youth',
#  '.',
#  'With',
#  'over',
#  '65',
#  '%',
#  'of',
#  'our',
#  'population',
#  'under',
#  'the',
#  'age',
#  'of',
#  '35',
#  ',',
#  'we',
#  'have',
#  'the',
#  'potential',
#  'to',
#  'be',
#  'the',
#  'world',
#  "'s",
#  'leaders',
#  'in',
#  'science',
#  ',',
#  'technology',
#  ',',
#  'arts',
#  ',',
#  'and',
#  'governance',
#  '.',
#  'But',
#  'to',
#  'achieve',
#  'this',
#  ',',
#  'we',
#  'must',
#  'first',
#  'dream',
#  '.',
#  'Dreams',
#  'are',
#  'not',
#  'what',
#  'you',
#  'see',
#  'while',
#  'sleeping',
#  ';',
#  'dreams',
#  'are',
#  'what',
#  'keep',
#  'you',
#  'awake',
#  'and',
#  'motivated',
#  'to',
#  'achieve',
#  'your',
#  'goals',
#  '.',
#  'History',
#  'is',
#  'witness',
#  'that',
#  'every',
#  'great',
#  'accomplishment',
#  'begins',
#  'with',
#  'a',
#  'dream—a',
#  'vision',
#  '.',
#  'When',
#  'we',
#  'dreamed',
#  'of',
#  'freedom',
#  ',',
#  'we',
#  'had',
#  'leaders',
#  'like',
#  'Mahatma',
#  'Gandhi',
#  'who',
#  'made',
#  'it',
#  'a',
#  'reality',
#  '.',
#  'When',
#  'we',
#  'dreamed',
#  'of',
#  'self-reliance',
#  ',',
#  'we',
#  'had',
#  'scientists',
#  ',',
#  'engineers',
#  ',',
#  'and',
#  'farmers',
#  'who',
#  'transformed',
#  'our',
#  'economy',
#  '.',
#  'Today',
#  ',',
#  'I',
#  'urge',
#  'each',
#  'of',
#  'you',
#  'to',
#  'dream',
#  'of',
#  'a',
#  'stronger',
#  ',',
#  'self-sufficient',
#  ',',
#  'and',
#  'united',
#  'India',
#  '.',
#  'Knowledge',
#  'is',
#  'the',
#  'foundation',
#  'of',
#  'progress',
#  '.',
#  'It',
#  'is',
#  'your',
#  'responsibility',
#  'to',
#  'constantly',
#  'learn',
#  ',',
#  'innovate',
#  ',',
#  'and',
#  'adapt',
#  '.',
#  'The',
#  'world',
#  'is',
#  'changing',
#  'rapidly',
#  'with',
#  'advancements',
#  'in',
#  'artificial',
#  'intelligence',
#  ',',
#  'clean',
#  'energy',
#  ',',
#  'and',
#  'space',
#  'exploration',
#  '.',
#  'We',
#  ',',
#  'as',
#  'Indians',
#  ',',
#  'have',
#  'the',
#  'capability',
#  'to',
#  'lead',
#  'in',
#  'these',
#  'fields',
#  '.',
#  'When',
#  'I',
#  'worked',
#  'on',
#  'India',
#  "'s",
#  'space',
#  'program',
#  ',',
#  'we',
#  'faced',
#  'countless',
#  'challenges',
#  '.',
#  'But',
#  'every',
#  'failure',
#  'taught',
#  'us',
#  'something',
#  'invaluable',
#  ',',
#  'and',
#  'eventually',
#  ',',
#  'we',
#  'succeeded',
#  '.',
#  'Remember',
#  ',',
#  'success',
#  'does',
#  'not',
#  'come',
#  'overnight—it',
#  'demands',
#  'hard',
#  'work',
#  ',',
#  'perseverance',
#  ',',
#  'and',
#  'teamwork',
#  '.']

# %%
porter_stemmer = nltk.stem.PorterStemmer()

# %%
porter_stemmer.stem(speech)
# Out:
# "good morning everyone,\nit is an honor to be with you today. i want to speak about a topic that is very close to my heart: the power of dreams and how they shape the future of a nation.\nindia is a country rich in culture, resources, and above all, its youth. with over 65% of our population under the age of 35, we have the potential to be the world's leaders in science, technology, arts, and governance. but to achieve this, we must first dream.\ndreams are not what you see while sleeping; dreams are what keep you awake and motivated to achieve your goals. history is witness that every great accomplishment begins with a dream—a vision.\nwhen we dreamed of freedom, we had leaders like mahatma gandhi who made it a reality. when we dreamed of self-reliance, we had scientists, engineers, and farmers who transformed our economy. today, i urge each of you to dream of a stronger, self-sufficient, and united india.\nknowledge is the foundation of progress. it is your responsibility to constantly learn, innovate, and adapt. the world is changing rapidly with advancements in artificial intelligence, clean energy, and space exploration. we, as indians, have the capability to lead in these fields.\nwhen i worked on india's space program, we faced countless challenges. but every failure taught us something invaluable, and eventually, we succeeded. remember, success does not come overnight—it demands hard work, perseverance, and teamwork."

# %%
new_list = words_list-stop_word
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 new_list = words_list-stop_word
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
set1 = set(words_list)
set2 = set(stop_word)
result = list(set1 - set2)

# %%
result
# Out:
# ['space',
#  'Knowledge',
#  '65',
#  'motivated',
#  'resources',
#  'work',
#  'History',
#  'freedom',
#  'first',
#  'The',
#  'science',
#  ';',
#  'scientists',
#  'program',
#  'Mahatma',
#  'challenges',
#  'self-sufficient',
#  'heart',
#  'With',
#  'arts',
#  'urge',
#  'awake',
#  'everyone',
#  'want',
#  'fields',
#  ',',
#  'must',
#  'It',
#  'success',
#  'teamwork',
#  '%',
#  'We',
#  'hard',
#  'engineers',
#  'close',
#  'youth',
#  'progress',
#  'today',
#  'rich',
#  'potential',
#  'exploration',
#  'learn',
#  'great',
#  'energy',
#  '.',
#  'taught',
#  'culture',
#  'world',
#  'worked',
#  'Gandhi',
#  'sleeping',
#  ':',
#  'something',
#  'shape',
#  'constantly',
#  'perseverance',
#  'speak',
#  'united',
#  'adapt',
#  'clean',
#  'failure',
#  'artificial',
#  'capability',
#  'eventually',
#  'lead',
#  'witness',
#  'intelligence',
#  'farmers',
#  'Good',
#  'governance',
#  'reality',
#  'Dreams',
#  'demands',
#  'dreamed',
#  'every',
#  'But',
#  'honor',
#  'advancements',
#  'Today',
#  'come',
#  'population',
#  'topic',
#  'dreams',
#  'self-reliance',
#  'stronger',
#  'morning',
#  'India',
#  'power',
#  'I',
#  'age',
#  'see',
#  'overnight—it',
#  'changing',
#  'made',
#  'keep',
#  'vision',
#  'like',
#  'accomplishment',
#  'rapidly',
#  'leaders',
#  'Indians',
#  'Remember',
#  'responsibility',
#  'economy',
#  'faced',
#  'country',
#  'goals',
#  'dream',
#  "'s",
#  'us',
#  'technology',
#  'dream—a',
#  'future',
#  'begins',
#  'When',
#  'succeeded',
#  'innovate',
#  'foundation',
#  'achieve',
#  '35',
#  'transformed',
#  'nation',
#  'countless',
#  'invaluable']

# %%
new_text = []
 for i in range in new_text:
